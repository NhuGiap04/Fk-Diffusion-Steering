# %%
# !nvidia-smi
# Out:
# Wed Apr  1 13:56:23 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-80GB          Off |   00000000:00:05.0 Off |                    0 |
# | N/A   33C    P0             55W /  400W |       0MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ### Setup Environment

# %%
# !git clone https://github.com/NhuGiap04/Fk-Diffusion-Steering.git
# Out:
# Cloning into 'Fk-Diffusion-Steering'...
# remote: Enumerating objects: 768, done.
# remote: Counting objects: 100% (504/504), done.
# remote: Compressing objects: 100% (406/406), done.
# remote: Total 768 (delta 140), reused 433 (delta 96), pack-reused 264 (from 2)
# Receiving objects: 100% (768/768), 202.54 MiB | 15.83 MiB/s, done.
# Resolving deltas: 100% (266/266), done.

# %%
# %cd Fk-Diffusion-Steering
# !git switch evo_v0.1
# !git pull
# Out:
# /content/Fk-Diffusion-Steering
# Already on 'evo_v0.1'
# Your branch is up to date with 'origin/evo_v0.1'.
# Already up to date.

# %%
# %pip install -r requirements.txt -q
# Out:
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.3/266.3 kB 32.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.1/165.1 kB 22.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.3/53.3 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 kB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 kB 16.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 4.7 MB/s eta 0:00:0000:0100:01m
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 102.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.4/63.4 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.9/164.9 kB 23.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.3/145.3 kB 20.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.5/320.5 kB 34.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 50.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 139.9 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.6/283.6 kB 31.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 23.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 90.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 450.7/450.7 kB 46.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 kB 15.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 796.4/796.4 kB 64.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.6/134.6 kB 18.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 66.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 164.8 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.0/131.0 kB 17.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 100.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 91.4 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 150.4 MB/s eta 0:00:0000:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 145.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.6/243.6 kB 30.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 20.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.7/107.7 kB 14.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.8/316.8 kB 37.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 508.0/508.0 kB 52.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 767.5/767.5 kB 66.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 796.9/796.9 kB 64.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 8.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.0/462.0 kB 28.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.2/38.2 MB 72.0 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 93.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 156.8 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 98.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 102.7 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.3/242.3 kB 30.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.2/797.2 MB 1.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 82.6 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 10.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 12.7 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 kB 34.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.4/128.4 kB 16.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.8/74.8 kB 9.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 23.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.9/336.9 kB 34.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 123.9 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 kB 20.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 6.6 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 143.8 MB/s eta 0:00:0000:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 105.2 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 68.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 21.3 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 46.4 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 20.7 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 13.2 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 14.7 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 11.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.3/25.3 MB 106.8 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 76.6 MB/s eta 0:00:00
#   Building wheel for args (setup.py) ... done
#   Building wheel for clint (setup.py) ... done
#   Building wheel for fairscale (pyproject.toml) ... done
#   Building editable for diffusers (pyproject.toml) ... done
#   Building wheel for clip (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipykernel==6.17.1, but you have ipykernel 6.29.5 which is incompatible.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 8.12.0 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.1 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.3 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.9.0 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 3.20.3 which is incompatible.
# dataproc-spark-connect 1.0.2 requires tqdm>=4.67, but you have tqdm 4.66.4 which is incompatible.
# ydf 0.15.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# tsfresh 0.21.1 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# google-api-core 2.30.0 requires protobuf<7.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# gradio 5.50.0 requires huggingface-hub<2.0,>=0.33.5, but you have huggingface-hub 0.27.1 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.3 which is incompatible.
# opentelemetry-proto 1.38.0 requires protobuf<7.0,>=5.0, but you have protobuf 3.20.3 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.3 which is incompatible.
# tobler 0.13.0 requires numpy>=2.0, but you have numpy 1.26.3 which is incompatible.
# tobler 0.13.0 requires tqdm>=4.67, but you have tqdm 4.66.4 which is incompatible.
# sentence-transformers 5.3.0 requires transformers<6.0.0,>=4.41.0, but you have transformers 4.37.2 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.3 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.3 which is incompatible.
# access 1.1.10.post3 requires scipy>=1.14.1, but you have scipy 1.13.1 which is incompatible.
# google-adk 1.27.1 requires requests<3.0.0,>=2.32.4, but you have requests 2.32.3 which is incompatible.
# grain 0.2.16 requires protobuf>=5.28.3, but you have protobuf 3.20.3 which is incompatible.
# tensorflow-metadata 1.17.3 requires protobuf>=4.25.2; python_version >= "3.11", but you have protobuf 3.20.3 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.3 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.3 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.3 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.3 which is incompatible.
# music21 9.9.1 requires numpy>=1.26.4, but you have numpy 1.26.3 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.3 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.3 which is incompatible.
# torchaudio 2.10.0+cu128 requires torch==2.10.0, but you have torch 2.4.0 which is incompatible.

# %% [markdown]
# ### Run Evaluation

# %%
# %cd text_to_image

# !bash launch_evolve.sh
# Out:
# [Errno 2] No such file or directory: 'text_to_image'
# /content/Fk-Diffusion-Steering/text_to_image
# 2026-04-01 14:32:26.125208: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775053946.146092   10153 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775053946.152507   10153 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775053946.168778   10153 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775053946.168811   10153 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775053946.168815   10153 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775053946.168818   10153 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Loading pipeline components...: 100% 7/7 [00:03<00:00,  1.98it/s]
# 100% 50/50 [00:36<00:00,  1.37it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# load checkpoint from /root/.cache/ImageReward/ImageReward.pt
# checkpoint loaded
# 100% 50/50 [00:18<00:00,  2.67it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=1/4 best_reward=1.0404 mean_reward=0.1897 std_reward=0.7583 min_reward=-1.0105 threshold=0.2845 accepted=4 rejected=4
# 100% 50/50 [00:18<00:00,  2.67it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=2/4 best_reward=1.0404 mean_reward=0.7791 std_reward=0.2176 min_reward=0.4382 threshold=0.8063 accepted=3 rejected=5
# 100% 50/50 [00:23<00:00,  2.11it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=3/4 best_reward=1.2123 mean_reward=0.9879 std_reward=0.1760 min_reward=0.6617 threshold=1.0099 accepted=5 rejected=3
# 100% 50/50 [00:13<00:00,  3.57it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=4/4 best_reward=1.3561 mean_reward=1.1258 std_reward=0.1551 min_reward=0.8782 threshold=1.1452 accepted=3 rejected=5
# [1/100] id=005695-0057 mean=1.1258 std=0.1451 max=1.3561 min=0.8782 loops=4 images=8 secs=128.12
# 100% 50/50 [00:36<00:00,  1.36it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# 100% 50/50 [00:13<00:00,  3.58it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=1/4 best_reward=0.5779 mean_reward=0.4439 std_reward=0.0988 min_reward=0.2978 threshold=0.4562 accepted=3 rejected=5
# 100% 50/50 [00:23<00:00,  2.11it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=2/4 best_reward=0.7795 mean_reward=0.5146 std_reward=0.2204 min_reward=0.0506 threshold=0.5421 accepted=5 rejected=3
# 100% 50/50 [00:13<00:00,  3.57it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=3/4 best_reward=0.8330 mean_reward=0.6089 std_reward=0.1460 min_reward=0.4284 threshold=0.6272 accepted=3 rejected=5
# 100% 50/50 [00:23<00:00,  2.11it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=4/4 best_reward=0.8330 mean_reward=0.5224 std_reward=0.2505 min_reward=0.0835 threshold=0.6403 accepted=3 rejected=5
# [2/100] id=005784-0093 mean=0.5224 std=0.2343 max=0.8330 min=0.0835 loops=4 images=8 secs=119.35
# 100% 50/50 [00:36<00:00,  1.36it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# 100% 50/50 [00:18<00:00,  2.66it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=1/4 best_reward=1.1510 mean_reward=0.9344 std_reward=0.1615 min_reward=0.7310 threshold=0.9546 accepted=4 rejected=4
# 100% 50/50 [00:18<00:00,  2.66it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=2/4 best_reward=1.1510 mean_reward=0.8802 std_reward=0.2339 min_reward=0.4499 threshold=0.9637 accepted=3 rejected=5
# 100% 50/50 [00:23<00:00,  2.11it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=3/4 best_reward=1.3308 mean_reward=0.9726 std_reward=0.2526 min_reward=0.4960 threshold=1.0041 accepted=4 rejected=4
# 100% 50/50 [00:18<00:00,  2.66it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=4/4 best_reward=1.3308 mean_reward=1.1508 std_reward=0.0912 min_reward=1.0251 threshold=1.1622 accepted=2 rejected=6
# [3/100] id=005848-0000 mean=1.1508 std=0.0854 max=1.3308 min=1.0251 loops=4 images=8 secs=124.35
# 100% 50/50 [00:36<00:00,  1.36it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# 100% 50/50 [00:13<00:00,  3.57it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=1/4 best_reward=0.9150 mean_reward=0.8401 std_reward=0.0586 min_reward=0.7489 threshold=0.8474 accepted=4 rejected=4
# 100% 50/50 [00:18<00:00,  2.66it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=2/4 best_reward=0.9150 mean_reward=0.8188 std_reward=0.0935 min_reward=0.6510 threshold=0.8518 accepted=4 rejected=4
# 100% 50/50 [00:18<00:00,  2.66it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=3/4 best_reward=0.9208 mean_reward=0.8318 std_reward=0.1056 min_reward=0.6386 threshold=0.8533 accepted=4 rejected=4
# 100% 50/50 [00:18<00:00,  2.66it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=4/4 best_reward=0.9208 mean_reward=0.8021 std_reward=0.1128 min_reward=0.6651 threshold=0.8542 accepted=4 rejected=4
# [4/100] id=005765-0094 mean=0.8021 std=0.1055 max=0.9208 min=0.6651 loops=4 images=8 secs=114.11
# 100% 50/50 [00:36<00:00,  1.36it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# 100% 50/50 [00:09<00:00,  5.32it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=1/4 best_reward=1.9885 mean_reward=1.9393 std_reward=0.0378 min_reward=1.8869 threshold=1.9440 accepted=4 rejected=4
# 100% 50/50 [00:18<00:00,  2.66it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=2/4 best_reward=1.9885 mean_reward=1.9398 std_reward=0.0691 min_reward=1.7762 threshold=1.9484 accepted=5 rejected=3
# 100% 50/50 [00:14<00:00,  3.57it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=3/4 best_reward=1.9885 mean_reward=1.9574 std_reward=0.0255 min_reward=1.9196 threshold=1.9606 accepted=5 rejected=3
# 100% 50/50 [00:14<00:00,  3.57it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=4/4 best_reward=1.9917 mean_reward=1.9597 std_reward=0.0372 min_reward=1.8803 threshold=1.9643 accepted=4 rejected=4
# [5/100] id=005846-0102 mean=1.9597 std=0.0348 max=1.9917 min=1.8803 loops=4 images=8 secs=99.06
# 100% 50/50 [00:36<00:00,  1.36it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# 100% 50/50 [00:23<00:00,  2.11it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=1/4 best_reward=1.4782 mean_reward=0.7439 std_reward=0.5400 min_reward=0.0472 threshold=0.8114 accepted=4 rejected=4
# 100% 50/50 [00:18<00:00,  2.66it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=2/4 best_reward=1.4782 mean_reward=1.0614 std_reward=0.3745 min_reward=0.5020 threshold=1.1082 accepted=3 rejected=5
# 100% 50/50 [00:23<00:00,  2.11it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=3/4 best_reward=1.4782 mean_reward=1.0801 std_reward=0.4511 min_reward=0.4310 threshold=1.1364 accepted=4 rejected=4
# 100% 50/50 [00:18<00:00,  2.66it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=4/4 best_reward=1.4782 mean_reward=1.1365 std_reward=0.4090 min_reward=0.3174 threshold=1.1876 accepted=4 rejected=4
# [6/100] id=005937-0170 mean=1.1365 std=0.3826 max=1.4782 min=0.3174 loops=4 images=8 secs=129.56
# 100% 50/50 [00:36<00:00,  1.36it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# 100% 50/50 [00:09<00:00,  5.33it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=1/4 best_reward=1.9640 mean_reward=1.8974 std_reward=0.0525 min_reward=1.8195 threshold=1.9040 accepted=5 rejected=3
# 100% 50/50 [00:13<00:00,  3.58it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=2/4 best_reward=1.9731 mean_reward=1.9098 std_reward=0.0608 min_reward=1.7877 threshold=1.9174 accepted=4 rejected=4
# 100% 50/50 [00:18<00:00,  2.66it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=3/4 best_reward=1.9731 mean_reward=1.9557 std_reward=0.0152 min_reward=1.9334 threshold=1.9576 accepted=5 rejected=3
# 100% 50/50 [00:13<00:00,  3.57it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=4/4 best_reward=1.9758 mean_reward=1.8195 std_reward=0.4124 min_reward=0.7989 threshold=2.0073 accepted=1 rejected=7
# [7/100] id=005895-0035 mean=1.8195 std=0.3858 max=1.9758 min=0.7989 loops=4 images=8 secs=98.92
# 100% 50/50 [00:36<00:00,  1.36it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# 100% 50/50 [00:13<00:00,  3.58it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=1/4 best_reward=1.2219 mean_reward=1.1346 std_reward=0.0469 min_reward=1.0809 threshold=1.1405 accepted=2 rejected=6
# 100% 50/50 [00:28<00:00,  1.78it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=2/4 best_reward=1.2219 mean_reward=1.1366 std_reward=0.0734 min_reward=1.0033 threshold=1.1458 accepted=4 rejected=4
# 100% 50/50 [00:18<00:00,  2.66it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=3/4 best_reward=1.2584 mean_reward=1.1749 std_reward=0.0606 min_reward=1.0605 threshold=1.1825 accepted=4 rejected=4
# 100% 50/50 [00:18<00:00,  2.66it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=4/4 best_reward=1.2584 mean_reward=1.2067 std_reward=0.0422 min_reward=1.1443 threshold=1.2120 accepted=4 rejected=4
# [8/100] id=005937-0167 mean=1.2067 std=0.0395 max=1.2584 min=1.1443 loops=4 images=8 secs=123.83
# 100% 50/50 [00:36<00:00,  1.36it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# 100% 50/50 [00:13<00:00,  3.57it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=1/4 best_reward=1.8003 mean_reward=1.4653 std_reward=0.1759 min_reward=1.1913 threshold=1.4873 accepted=3 rejected=5
# 100% 50/50 [00:23<00:00,  2.11it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=2/4 best_reward=1.8003 mean_reward=1.4132 std_reward=0.2609 min_reward=0.9812 threshold=1.4979 accepted=3 rejected=5
# 100% 50/50 [00:23<00:00,  2.11it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=3/4 best_reward=1.8769 mean_reward=1.5143 std_reward=0.3032 min_reward=0.9804 threshold=1.5522 accepted=4 rejected=4
# 100% 50/50 [00:18<00:00,  2.66it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=4/4 best_reward=1.8769 mean_reward=1.5576 std_reward=0.2585 min_reward=1.1406 threshold=1.5899 accepted=4 rejected=4
# [9/100] id=005912-0052 mean=1.5576 std=0.2418 max=1.8769 min=1.1406 loops=4 images=8 secs=124.54
# 100% 50/50 [00:36<00:00,  1.36it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# 100% 50/50 [00:23<00:00,  2.11it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=1/4 best_reward=1.4159 mean_reward=0.9924 std_reward=0.2800 min_reward=0.5888 threshold=1.0274 accepted=4 rejected=4
# 100% 50/50 [00:18<00:00,  2.66it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=2/4 best_reward=1.4159 mean_reward=0.9203 std_reward=0.4946 min_reward=-0.2140 threshold=1.0542 accepted=4 rejected=4
# 100% 50/50 [00:18<00:00,  2.66it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=3/4 best_reward=1.4159 mean_reward=0.9953 std_reward=0.2706 min_reward=0.5823 threshold=1.0291 accepted=4 rejected=4
# 100% 50/50 [00:18<00:00,  2.66it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=4/4 best_reward=1.4159 mean_reward=1.0665 std_reward=0.2548 min_reward=0.5891 threshold=1.0983 accepted=4 rejected=4
# [10/100] id=005903-0142 mean=1.0665 std=0.2383 max=1.4159 min=0.5891 loops=4 images=8 secs=124.40
# 100% 50/50 [00:36<00:00,  1.36it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# 100% 50/50 [00:18<00:00,  2.66it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=1/4 best_reward=1.2762 mean_reward=0.3942 std_reward=0.4140 min_reward=-0.0348 threshold=0.4459 accepted=3 rejected=5
# 100% 50/50 [00:23<00:00,  2.10it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=2/4 best_reward=1.2762 mean_reward=0.4254 std_reward=0.5346 min_reward=-0.1533 threshold=0.4922 accepted=4 rejected=4
# 100% 50/50 [00:18<00:00,  2.66it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=3/4 best_reward=1.2762 mean_reward=0.5204 std_reward=0.4284 min_reward=0.0968 threshold=0.5739 accepted=3 rejected=5
# 100% 50/50 [00:23<00:00,  2.10it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=4/4 best_reward=1.2762 mean_reward=0.6483 std_reward=0.3845 min_reward=0.1948 threshold=0.6963 accepted=3 rejected=5
# [11/100] id=005895-0048 mean=0.6483 std=0.3596 max=1.2762 min=0.1948 loops=4 images=8 secs=129.72
# 100% 50/50 [00:36<00:00,  1.36it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# 100% 50/50 [00:18<00:00,  2.66it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=1/4 best_reward=1.6977 mean_reward=0.4800 std_reward=0.6392 min_reward=-0.2558 threshold=0.5598 accepted=5 rejected=3
# 100% 50/50 [00:13<00:00,  3.58it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=2/4 best_reward=1.6977 mean_reward=0.9093 std_reward=0.4654 min_reward=0.5243 threshold=0.9675 accepted=2 rejected=6
# 100% 50/50 [00:28<00:00,  1.78it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=3/4 best_reward=1.6977 mean_reward=0.8881 std_reward=0.5824 min_reward=0.0987 threshold=0.9821 accepted=4 rejected=4
# 100% 50/50 [00:18<00:00,  2.66it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=4/4 best_reward=1.6977 mean_reward=0.9440 std_reward=0.6032 min_reward=-0.0707 threshold=1.0194 accepted=4 rejected=4
# [12/100] id=007048-0049 mean=0.9440 std=0.5643 max=1.6977 min=-0.0707 loops=4 images=8 secs=123.98
# 100% 50/50 [00:36<00:00,  1.36it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# 100% 50/50 [00:05<00:00,  8.83it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=1/4 best_reward=0.8424 mean_reward=0.5668 std_reward=0.1304 min_reward=0.4489 threshold=0.5830 accepted=3 rejected=5
# 100% 50/50 [00:23<00:00,  2.11it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=2/4 best_reward=0.8424 mean_reward=0.5011 std_reward=0.2488 min_reward=0.0463 threshold=0.5978 accepted=4 rejected=4
# 100% 50/50 [00:18<00:00,  2.66it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=3/4 best_reward=0.8424 mean_reward=0.6322 std_reward=0.1047 min_reward=0.4649 threshold=0.6453 accepted=2 rejected=6
# 100% 50/50 [00:28<00:00,  1.78it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=4/4 best_reward=0.8424 mean_reward=0.7098 std_reward=0.0853 min_reward=0.5878 threshold=0.7205 accepted=3 rejected=5
# [13/100] id=007086-0087 mean=0.7098 std=0.0798 max=0.8424 min=0.5878 loops=4 images=8 secs=120.14
# 100% 50/50 [00:36<00:00,  1.36it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# 100% 50/50 [00:14<00:00,  3.57it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=1/4 best_reward=0.8386 mean_reward=0.3165 std_reward=0.3325 min_reward=-0.1965 threshold=0.3580 accepted=4 rejected=4
# 100% 50/50 [00:18<00:00,  2.66it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=2/4 best_reward=0.8386 mean_reward=0.5117 std_reward=0.2865 min_reward=-0.0837 threshold=0.5475 accepted=5 rejected=3
# 100% 50/50 [00:14<00:00,  3.57it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=3/4 best_reward=0.8644 mean_reward=0.6437 std_reward=0.2382 min_reward=0.0996 threshold=0.6735 accepted=3 rejected=5
# 100% 50/50 [00:23<00:00,  2.10it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=4/4 best_reward=0.9139 mean_reward=0.6632 std_reward=0.2335 min_reward=0.2259 threshold=0.6924 accepted=4 rejected=4
# [14/100] id=007109-0000 mean=0.6632 std=0.2185 max=0.9139 min=0.2259 loops=4 images=8 secs=114.35
# 100% 50/50 [00:36<00:00,  1.36it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# 100% 50/50 [00:14<00:00,  3.57it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=1/4 best_reward=1.6082 mean_reward=1.2408 std_reward=0.3421 min_reward=0.7426 threshold=1.2836 accepted=5 rejected=3
# 100% 50/50 [00:14<00:00,  3.57it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=2/4 best_reward=1.6082 mean_reward=1.4077 std_reward=0.1576 min_reward=1.1196 threshold=1.4274 accepted=4 rejected=4
# 100% 50/50 [00:18<00:00,  2.66it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=3/4 best_reward=1.7106 mean_reward=1.3343 std_reward=0.4437 min_reward=0.3998 threshold=1.4631 accepted=6 rejected=2
# 100% 50/50 [00:09<00:00,  5.31it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=4/4 best_reward=1.7106 mean_reward=1.5173 std_reward=0.1134 min_reward=1.3172 threshold=1.5315 accepted=2 rejected=6
# [15/100] id=007029-0027 mean=1.5173 std=0.1061 max=1.7106 min=1.3172 loops=4 images=8 secs=99.14
# 100% 50/50 [00:36<00:00,  1.36it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# 100% 50/50 [00:09<00:00,  5.33it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=1/4 best_reward=1.9255 mean_reward=1.8569 std_reward=0.0634 min_reward=1.7167 threshold=1.8648 accepted=4 rejected=4
# 100% 50/50 [00:18<00:00,  2.66it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=2/4 best_reward=1.9255 mean_reward=1.7708 std_reward=0.1884 min_reward=1.3808 threshold=1.8805 accepted=2 rejected=6
# 100% 50/50 [00:28<00:00,  1.78it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=3/4 best_reward=1.9255 mean_reward=1.7740 std_reward=0.3675 min_reward=0.8656 threshold=1.9028 accepted=5 rejected=3
# 100% 50/50 [00:14<00:00,  3.57it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=4/4 best_reward=1.9255 mean_reward=1.8717 std_reward=0.0891 min_reward=1.6647 threshold=1.8828 accepted=6 rejected=2
# [16/100] id=007086-0024 mean=1.8717 std=0.0833 max=1.9255 min=1.6647 loops=4 images=8 secs=114.00
# 100% 50/50 [00:36<00:00,  1.36it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# 100% 50/50 [00:23<00:00,  2.11it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=1/4 best_reward=1.6268 mean_reward=1.4026 std_reward=0.1783 min_reward=1.1280 threshold=1.4249 accepted=4 rejected=4
# 100% 50/50 [00:18<00:00,  2.66it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=2/4 best_reward=1.6268 mean_reward=1.5223 std_reward=0.0640 min_reward=1.4530 threshold=1.5303 accepted=4 rejected=4
# 100% 50/50 [00:18<00:00,  2.66it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=3/4 best_reward=1.6268 mean_reward=1.5475 std_reward=0.0574 min_reward=1.4568 threshold=1.5546 accepted=4 rejected=4
# 100% 50/50 [00:18<00:00,  2.65it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=4/4 best_reward=1.6268 mean_reward=1.5516 std_reward=0.0697 min_reward=1.4193 threshold=1.5603 accepted=5 rejected=3
# [17/100] id=007109-0002 mean=1.5516 std=0.0652 max=1.6268 min=1.4193 loops=4 images=8 secs=124.46
# 100% 50/50 [00:36<00:00,  1.36it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# 100% 50/50 [00:14<00:00,  3.57it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=1/4 best_reward=1.6906 mean_reward=1.5869 std_reward=0.1095 min_reward=1.3834 threshold=1.6006 accepted=5 rejected=3
# 100% 50/50 [00:14<00:00,  3.57it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=2/4 best_reward=1.7093 mean_reward=1.6494 std_reward=0.0514 min_reward=1.5450 threshold=1.6559 accepted=4 rejected=4
# 100% 50/50 [00:18<00:00,  2.66it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=3/4 best_reward=1.7481 mean_reward=1.6963 std_reward=0.0257 min_reward=1.6592 threshold=1.6995 accepted=2 rejected=6
# 100% 50/50 [00:28<00:00,  1.77it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=4/4 best_reward=1.8577 mean_reward=1.7170 std_reward=0.0858 min_reward=1.5514 threshold=1.7278 accepted=3 rejected=5
# [18/100] id=007045-0013 mean=1.7170 std=0.0803 max=1.8577 min=1.5514 loops=4 images=8 secs=119.05
# 100% 50/50 [00:36<00:00,  1.36it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# 100% 50/50 [00:13<00:00,  3.57it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=1/4 best_reward=1.8434 mean_reward=1.6292 std_reward=0.2659 min_reward=1.1267 threshold=1.6624 accepted=6 rejected=2
# 100% 50/50 [00:09<00:00,  5.33it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=2/4 best_reward=1.8434 mean_reward=1.7612 std_reward=0.0533 min_reward=1.6892 threshold=1.7679 accepted=3 rejected=5
# 100% 50/50 [00:23<00:00,  2.11it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=3/4 best_reward=1.8434 mean_reward=1.1596 std_reward=0.6627 min_reward=-0.0790 threshold=1.8440 accepted=1 rejected=7
# 100% 50/50 [00:32<00:00,  1.52it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=4/4 best_reward=1.8603 mean_reward=1.2074 std_reward=0.6890 min_reward=0.1497 threshold=1.8473 accepted=1 rejected=7
# [19/100] id=007135-0056 mean=1.2074 std=0.6445 max=1.8603 min=0.1497 loops=4 images=8 secs=124.34
# 100% 50/50 [00:36<00:00,  1.36it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
#  30% 15/50 [00:04<00:09,  3.55it/s]
# Traceback (most recent call last):
#   File "/content/Fk-Diffusion-Steering/text_to_image/launch_evolve_runs.py", line 251, in <module>
#     main(get_args())
#   File "/content/Fk-Diffusion-Steering/text_to_image/launch_evolve_runs.py", line 111, in main
#     loop_out = iterative_sample_with_stein(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Fk-Diffusion-Steering/text_to_image/evolve_diffusers/steer_pipeline.py", line 676, in iterative_sample_with_stein
#     result, latent_trajectory = steer_sample(**steer_sample_kwargs)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Fk-Diffusion-Steering/text_to_image/evolve_diffusers/steer_pipeline.py", line 276, in steer_sample
#     result = model(
#              ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Fk-Diffusion-Steering/text_to_image/evolve_diffusers/pipeline_sdxl.py", line 824, in __call__
# ^C
