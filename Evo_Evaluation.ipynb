# %%
# !nvidia-smi
# Out:
# Thu Apr  2 16:12:09 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-80GB          Off |   00000000:00:05.0 Off |                    0 |
# | N/A   31C    P0             54W /  400W |       0MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ### Setup Environment

# %%
# !git clone https://github.com/NhuGiap04/Fk-Diffusion-Steering.git
# Out:
# Cloning into 'Fk-Diffusion-Steering'...
# remote: Enumerating objects: 790, done.
# remote: Counting objects: 100% (526/526), done.
# remote: Compressing objects: 100% (423/423), done.
# remote: Total 790 (delta 157), reused 443 (delta 100), pack-reused 264 (from 2)
# Receiving objects: 100% (790/790), 202.56 MiB | 15.31 MiB/s, done.
# Resolving deltas: 100% (283/283), done.

# %%
# %cd Fk-Diffusion-Steering
# !git switch evo_v0.2
# !git pull
# Out:
# /content/Fk-Diffusion-Steering
# Already on 'evo_v0.2'
# Your branch is up to date with 'origin/evo_v0.2'.
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 367 bytes | 367.00 KiB/s, done.
# From https://github.com/NhuGiap04/Fk-Diffusion-Steering
#    7fd6c78..e6942c6  evo_v0.2   -> origin/evo_v0.2
# Updating 7fd6c78..e6942c6
# Fast-forward
#  text_to_image/launch_evolve.sh | 4 ++--
#  1 file changed, 2 insertions(+), 2 deletions(-)

# %%
# %pip install -r requirements.txt -q
# Out:
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.3/266.3 kB 30.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.1/165.1 kB 18.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.3/53.3 kB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 kB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 kB 15.2 MB/s eta 0:00:00
#      / 4.3 MB 6.5 MB/s 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 94.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.4/63.4 kB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.9/164.9 kB 18.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.3/145.3 kB 17.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.5/320.5 kB 33.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 45.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 114.7 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.6/283.6 kB 30.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 24.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 130.4 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 450.7/450.7 kB 43.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 8.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 kB 14.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 796.4/796.4 kB 60.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.6/134.6 kB 16.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 71.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 124.0 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.0/131.0 kB 16.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 95.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 84.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 149.0 MB/s eta 0:00:0000:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 133.3 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.6/243.6 kB 28.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 20.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.7/107.7 kB 13.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.8/316.8 kB 34.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 508.0/508.0 kB 46.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 767.5/767.5 kB 59.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 796.9/796.9 kB 65.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.0/462.0 kB 42.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.2/38.2 MB 67.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 83.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 109.8 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 102.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 129.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.3/242.3 kB 28.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.2/797.2 MB 1.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 128.7 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 9.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 12.2 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 kB 34.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.4/128.4 kB 16.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.8/74.8 kB 9.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 23.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.9/336.9 kB 38.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 166.6 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 kB 24.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 6.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 20.8 MB/s eta 0:00:00:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 101.4 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 64.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 12.9 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 21.1 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 13.5 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 9.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 11.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.3/25.3 MB 102.0 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 44.6 MB/s eta 0:00:0000:01
#   Building wheel for args (setup.py) ... done
#   Building wheel for clint (setup.py) ... done
#   Building wheel for fairscale (pyproject.toml) ... done
#   Building editable for diffusers (pyproject.toml) ... done
#   Building wheel for clip (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipykernel==6.17.1, but you have ipykernel 6.29.5 which is incompatible.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 8.12.0 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.1 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.3 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.3 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.3 which is incompatible.
# dataproc-spark-connect 1.0.2 requires tqdm>=4.67, but you have tqdm 4.66.4 which is incompatible.
# ydf 0.15.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.3 which is incompatible.
# gradio 5.50.0 requires huggingface-hub<2.0,>=0.33.5, but you have huggingface-hub 0.27.1 which is incompatible.
# tsfresh 0.21.1 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.3 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.3 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.9.0 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 3.20.3 which is incompatible.
# google-adk 1.27.1 requires requests<3.0.0,>=2.32.4, but you have requests 2.32.3 which is incompatible.
# google-api-core 2.30.0 requires protobuf<7.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# opentelemetry-proto 1.38.0 requires protobuf<7.0,>=5.0, but you have protobuf 3.20.3 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.3 which is incompatible.
# tensorflow-metadata 1.17.3 requires protobuf>=4.25.2; python_version >= "3.11", but you have protobuf 3.20.3 which is incompatible.
# sentence-transformers 5.3.0 requires transformers<6.0.0,>=4.41.0, but you have transformers 4.37.2 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.3 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.3 which is incompatible.
# grain 0.2.16 requires protobuf>=5.28.3, but you have protobuf 3.20.3 which is incompatible.
# torchaudio 2.10.0+cu128 requires torch==2.10.0, but you have torch 2.4.0 which is incompatible.
# tobler 0.13.0 requires numpy>=2.0, but you have numpy 1.26.3 which is incompatible.
# tobler 0.13.0 requires tqdm>=4.67, but you have tqdm 4.66.4 which is incompatible.
# music21 9.9.1 requires numpy>=1.26.4, but you have numpy 1.26.3 which is incompatible.
# access 1.1.10.post3 requires scipy>=1.14.1, but you have scipy 1.13.1 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.3 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.3 which is incompatible.

# %% [markdown]
# ### Run Evaluation

# %%
# %cd text_to_image

# !bash launch_evolve.sh
# Out:
# [Errno 2] No such file or directory: 'text_to_image'
# /content/Fk-Diffusion-Steering/text_to_image
# 2026-04-02 17:11:56.862602: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775149916.883387   16761 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775149916.889846   16761 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775149916.905903   16761 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775149916.905929   16761 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775149916.905932   16761 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775149916.905935   16761 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Loading pipeline components...: 100% 7/7 [00:03<00:00,  2.23it/s]
# 100% 50/50 [00:36<00:00,  1.38it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# load checkpoint from /root/.cache/ImageReward/ImageReward.pt
# checkpoint loaded
# 100% 50/50 [00:18<00:00,  2.69it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=1/2 best_reward=1.0404 mean_reward=0.2820 std_reward=0.6492 min_reward=-0.6523 threshold=0.2820 accepted=4 rejected=4
# 100% 50/50 [00:18<00:00,  2.69it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=2/2 best_reward=1.1272 mean_reward=0.8720 std_reward=0.2144 min_reward=0.5075 threshold=0.8720 accepted=4 rejected=4
# [1/100] id=005695-0057 mean=0.8720 std=0.2005 max=1.1272 min=0.5075 loops=2 images=8 secs=245.11
# 100% 50/50 [00:36<00:00,  1.38it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# 100% 50/50 [00:13<00:00,  3.60it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=1/2 best_reward=0.5779 mean_reward=0.4372 std_reward=0.1197 min_reward=0.2330 threshold=0.4372 accepted=5 rejected=3
# 100% 50/50 [00:13<00:00,  3.61it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=2/2 best_reward=0.6100 mean_reward=0.4185 std_reward=0.3118 min_reward=-0.3416 threshold=0.4372 accepted=7 rejected=1
# [2/100] id=005784-0093 mean=0.4185 std=0.2917 max=0.6100 min=-0.3416 loops=2 images=8 secs=225.46
# 100% 50/50 [00:36<00:00,  1.38it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# 100% 50/50 [00:18<00:00,  2.69it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=1/2 best_reward=1.1510 mean_reward=0.9281 std_reward=0.1754 min_reward=0.5488 threshold=0.9281 accepted=6 rejected=2
# 100% 50/50 [00:09<00:00,  5.39it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=2/2 best_reward=1.1510 mean_reward=0.9304 std_reward=0.1523 min_reward=0.6885 threshold=0.9304 accepted=6 rejected=2
# [3/100] id=005848-0000 mean=0.9304 std=0.1424 max=1.1510 min=0.6885 loops=2 images=8 secs=228.38
# 100% 50/50 [00:36<00:00,  1.38it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# 100% 50/50 [00:13<00:00,  3.60it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=1/2 best_reward=0.9150 mean_reward=0.8261 std_reward=0.0682 min_reward=0.7048 threshold=0.8261 accepted=4 rejected=4
# 100% 50/50 [00:18<00:00,  2.69it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=2/2 best_reward=1.0022 mean_reward=0.8713 std_reward=0.0891 min_reward=0.6960 threshold=0.8713 accepted=4 rejected=4
# [4/100] id=005765-0094 mean=0.8713 std=0.0833 max=1.0022 min=0.6960 loops=2 images=8 secs=231.66
# 100% 50/50 [00:36<00:00,  1.38it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# 100% 50/50 [00:09<00:00,  5.36it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=1/2 best_reward=1.9885 mean_reward=1.9442 std_reward=0.0383 min_reward=1.8869 threshold=1.9442 accepted=5 rejected=3
# 100% 50/50 [00:13<00:00,  3.61it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=2/2 best_reward=1.9885 mean_reward=1.9555 std_reward=0.0264 min_reward=1.9132 threshold=1.9555 accepted=6 rejected=2
# [5/100] id=005846-0102 mean=1.9555 std=0.0247 max=1.9885 min=1.9132 loops=2 images=8 secs=222.76
# 100% 50/50 [00:36<00:00,  1.38it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# 100% 50/50 [00:23<00:00,  2.13it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=1/2 best_reward=1.4782 mean_reward=0.8126 std_reward=0.4450 min_reward=0.3140 threshold=0.8126 accepted=3 rejected=5
# 100% 50/50 [00:23<00:00,  2.13it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=2/2 best_reward=1.4782 mean_reward=0.8361 std_reward=0.4777 min_reward=0.2205 threshold=0.8361 accepted=3 rejected=5
# [6/100] id=005937-0170 mean=0.8361 std=0.4469 max=1.4782 min=0.2205 loops=2 images=8 secs=252.92
# 100% 50/50 [00:36<00:00,  1.38it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# 100% 50/50 [00:09<00:00,  5.37it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=1/2 best_reward=1.9640 mean_reward=1.8933 std_reward=0.0502 min_reward=1.8195 threshold=1.8933 accepted=4 rejected=4
# 100% 50/50 [00:18<00:00,  2.69it/s]
# `metric_to_chase` will be ignored as it only applies to 'LLMGrader' as the `reward_name`
# loop=2/2 best_reward=1.9719 mean_reward=1.8625 std_reward=0.2012 min_reward=1.3723 threshold=1.8933 accepted=6 rejected=2
# [7/100] id=005895-0035 mean=1.8625 std=0.1882 max=1.9719 min=1.3723 loops=2 images=8 secs=216.29
#  58% 29/50 [00:20<00:15,  1.38it/s]^C
